# %%
from ultralytics import YOLO

# %%
model = YOLO("../models/model.pt")

# %%
model.export(format='tflite', optimize=True)
# Out:
# Ultralytics 8.3.75 🚀 Python-3.10.15 torch-2.6.0 CPU (Apple M1)
# YOLOv10n summary (fused): 285 layers, 2,707,676 parameters, 0 gradients, 8.3 GFLOPs
#
# PyTorch: starting from '../models/model.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 300, 6) (21.4 MB)
#
# TensorFlow SavedModel: starting export with tensorflow 2.18.0...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/calibration_image_sample_data_20x128x128x3_float32.npy.zip to 'calibration_image_sample_data_20x128x128x3_float32.npy.zip'...
# 100%|██████████| 1.11M/1.11M [00:00<00:00, 30.8MB/s]
# Unzipping calibration_image_sample_data_20x128x128x3_float32.npy.zip to /Users/pedromira/Documents/frtl_stage_four_vision/python/calibration_image_sample_data_20x128x128x3_float32.npy...: 100%|██████████| 1/1 [00:00<00:00, 52.47file/s]
# ONNX: starting export with onnx 1.17.0 opset 19...
# ONNX: slimming with onnxslim 0.1.48...
# ONNX: export success ✅ 2.0s, saved as '../models/model.onnx' (9.0 MB)
# TensorFlow SavedModel: starting TFLite export with onnx2tf 1.26.3...
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1739845069.879226  486098 devices.cc:76] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0 (Note: TensorFlow was not compiled with CUDA or ROCm support)
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1739845069.879846  486098 single_machine.cc:361] Starting new session
# W0000 00:00:1739845070.573057  486098 tf_tfl_flatbuffer_helpers.cc:365] Ignored output_format.
# W0000 00:00:1739845070.573073  486098 tf_tfl_flatbuffer_helpers.cc:368] Ignored drop_control_dependency.
# I0000 00:00:1739845071.255560  486098 devices.cc:76] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0 (Note: TensorFlow was not compiled with CUDA or ROCm support)
# I0000 00:00:1739845071.255624  486098 single_machine.cc:361] Starting new session
# W0000 00:00:1739845071.756585  486098 tf_tfl_flatbuffer_helpers.cc:365] Ignored output_format.
# W0000 00:00:1739845071.756606  486098 tf_tfl_flatbuffer_helpers.cc:368] Ignored drop_control_dependency.
# TensorFlow SavedModel: export success ✅ 36.0s, saved as '../models/model_saved_model' (23.3 MB)
#
# TensorFlow Lite: starting export with tensorflow 2.18.0...
# TensorFlow Lite: export success ✅ 0.0s, saved as '../models/model_saved_model/model_float32.tflite' (9.2 MB)
#
# Export complete (36.5s)
# Results saved to /Users/pedromira/Documents/frtl_stage_four_vision/models
# Predict:         yolo predict task=detect model=../models/model_saved_model/model_float32.tflite imgsz=640
# Validate:        yolo val task=detect model=../models/model_saved_model/model_float32.tflite imgsz=640 data=/home/jovyan/shares/SR003.nfs2/nuzhdin/hagrid_exps/yolov10/ultralytics/cfg/datasets/hagrid_v2_gestures.yaml
# Visualize:       https://netron.app
# '../models/model_saved_model/model_float32.tflite'

# %%
model.export(format="onnx")  # Convert to ONNX
